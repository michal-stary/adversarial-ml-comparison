# %% [markdown]
# # explore FMN2

# %%
from logging_ import Logger
import matplotlib.pyplot as plt
import pandas as pd

# %load_ext autoreload
# %autoreload 2

from scores import SCORES
from settings import OPTIMAL_HYPERS_BEST, OPTIMAL_HYPERS_NORM
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logger = Logger(logs_dir="logs_fmn_projections")

# %%
logger.load_all()
logger.logs_dir="logs_art_add_fmn_to_aa"
logger.load_all()
logger.logs_dir="logs_targeted"
logger.load_all()

# %%
from scores import SCORES
from settings import OPTIMAL_HYPERS_BEST, OPTIMAL_HYPERS_NORM
# DECIDE WHETHER TO add "all" versions wrt individual samples or not


# for norm in OPTIMAL_HYPERS_NORM:
#         for model in SCORES[norm][0]:
#             logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-auto_all-model-{model}", [*logger.where(norm=norm, attack="aa", model=model).keys()])
OPTIMAL_HYPERS=OPTIMAL_HYPERS_NORM
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        for attack in ["fmn_t", "alma_t"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm]).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            slow_ids = [*filter(is_slow, run_ids)]
            if slow_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack[:-2]}_all-model-{model}-level-norm-steps-1001", slow_ids)
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack[:-2]}_all-model-{model}-level-norm-steps-101", quick_ids)
OPTIMAL_HYPERS=OPTIMAL_HYPERS_BEST
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        for attack in ["fmn_t", "alma_t"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm]).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            slow_ids = [*filter(is_slow, run_ids)]
            if slow_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack[:-2]}_all-model-{model}-level-sample-steps-1001", slow_ids)
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack[:-2]}_all-model-{model}-level-sample-steps-101", quick_ids)

OPTIMAL_HYPERS = OPTIMAL_HYPERS_NORM

# %%
# FMN 100 untargeted + 100 targeted to each class

OPTIMAL_HYPERS=OPTIMAL_HYPERS_NORM
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn", "alma"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm]).keys())] + [*list(logger.where(model=model, attack=attack+"_all", level="norm", **OPTIMAL_HYPERS[norm]).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_all-model-{model}-level-norm-steps-101", quick_ids)

OPTIMAL_HYPERS=OPTIMAL_HYPERS_BEST
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn", "alma"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm]).keys())] + [*list(logger.where(model=model, attack=attack+"_all", level="sample",**OPTIMAL_HYPERS[norm]).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_all-model-{model}-level-sample-steps-101", quick_ids)
                
OPTIMAL_HYPERS = OPTIMAL_HYPERS_NORM

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"attack":"fmn_all"}, compare_on="level")

# %%
# Ensemble FMN2 for L1

OPTIMAL_HYPERS=OPTIMAL_HYPERS_BEST
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn2"]:
            run_ids = [*list(logger.where(model=model, norm=norm, attack=attack, γ_final="x", fmn_init=True, balanced_init=False, targeted_line=False).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            for i in quick_ids:
                print(i)
            print()
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_all-model-{model}-α_init-ensemble-steps-101", quick_ids)
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_all-model-{model}-steps-101", quick_ids)

                
OPTIMAL_HYPERS = OPTIMAL_HYPERS_NORM
# Out:
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-30
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-20
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1

# %% [markdown]
# # Detailed exploration of differences between multitargeted and init in L1

# %% [markdown]
# ## Compare fixed 11*100 with fixed 300 fixed and fixed and fmn2 sample with all inits

# %%
s = {**{"norm":"L1", "balanced_init": "False", "top_explore": 10, "fmn_init":True, "targeted_line":False, "γ_final":"x", "binary_search_steps":"x"},
**{"level": "norm", "target":"x"},
**{"α_init": "1", "ifmn_α_init":"5"}}
[*logger.where(**s).keys()]
# Out:
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Maini2020MultipleAVG-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Maini2020MultipleAVG-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Maini2020MultipleMSD-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Maini2020MultipleMSD-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Augustin2020Adversarial_34_10_extra-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Augustin2020Adversarial_34_10_extra-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Engstrom2019Robustness_l2-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Engstrom2019Robustness_l2-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Rice2020Overfitting-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Rice2020Overfitting-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Xiao2020Enhancing-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Xiao2020Enhancing-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Engstrom2019Robustness_linf-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Engstrom2019Robustness_linf-level-norm-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleAVG-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleMSD-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Augustin2020Adversarial_34_10_extra-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_l2-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Rice2020Overfitting-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_linf-steps-101']

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings=s, compare_on="attack")

# %% [markdown]
# ## Add FMN2 ensemble line with fixed alpha init
# -- to see if tuning alpha init is enough or not

# %%
# Ensemble FMN2

OPTIMAL_HYPERS=OPTIMAL_HYPERS_BEST
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn2"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm], γ_final="x", fmn_init=True, balanced_init=False, targeted_line=False).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            for i in quick_ids:
                print(i)
            print()
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_allf-model-{model}-α_init-ensemble-steps-101", quick_ids)
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_allf-model-{model}-steps-101", quick_ids)

                
OPTIMAL_HYPERS = OPTIMAL_HYPERS_NORM

# %%
s = {**{"norm":"L1", "balanced_init": "False", "top_explore": 10, "fmn_init":True, "targeted_line":False, "γ_final":"x", "binary_search_steps":"x"},
**{"level": "sample", "target":"x"},
**{"α_init": "1", "ifmn_α_init":"5"}}
[*logger.where(**s).keys()]
# Out:
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Maini2020MultipleAVG-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Maini2020MultipleAVG-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Maini2020MultipleMSD-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Maini2020MultipleMSD-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Augustin2020Adversarial_34_10_extra-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Augustin2020Adversarial_34_10_extra-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Engstrom2019Robustness_l2-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Engstrom2019Robustness_l2-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Rice2020Overfitting-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Rice2020Overfitting-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Xiao2020Enhancing-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Xiao2020Enhancing-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Engstrom2019Robustness_linf-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Engstrom2019Robustness_linf-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleAVG-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleMSD-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Augustin2020Adversarial_34_10_extra-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_l2-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Rice2020Overfitting-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_linf-steps-101']

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings=s, compare_on="attack")

# %% [markdown]
# ## Compare FMN2 ensemble when init_aplha = aplha and when not

# %%
# Ensemble FMN2

OPTIMAL_HYPERS=OPTIMAL_HYPERS_BEST
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn2"]:
            run_ids = [*list(logger.where(model=model, attack=attack, norm=norm, γ_final="x", fmn_init=True, balanced_init=False, targeted_line=False).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            is_same = lambda x: logger.value_from_id("α_init", x) == logger.value_from_id("ifmn_α_init", x)
            quick_ids = [*filter(lambda x: (not is_slow(x)) and is_same(x) , run_ids)]
            for i in quick_ids:
                print(i)
            print()
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_allp-model-{model}-α_init-ensemble-steps-101", quick_ids)
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_allp-model-{model}-steps-101", quick_ids)

                
OPTIMAL_HYPERS = OPTIMAL_HYPERS_NORM
# Out:
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
#
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-True-steps-100-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={**s, "steepest_line":False}, compare_on="croce_l1")

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={**s, "croce_l1":False}, compare_on="steepest_line")

# %%
logger.plot_SE_grid(where_settings={"top_explore": "10", "attack": "fmn2", "fmn_init": "True", "targeted_line":"False"}, figsize=(60,15), compare_on="α_init")

# %%
logger.plot_SE_grid(where_settings={"top_explore": "10", "attack": "fmn_all"}, figsize=(60,15), compare_on="level")

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"target":"x", "top_explore": "10", "targeted_line": "False", "balanced_init": "False"})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "Linf", "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line": "False", "balanced_init": "False", "α_init":OPTIMAL_HYPERS_NORM["Linf"]["α_init"]})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1", "α_init":OPTIMAL_HYPERS_NORM["L1"]["α_init"], "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L2", "α_init":OPTIMAL_HYPERS_NORM["L2"]["α_init"], "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "Linf", "α_init":OPTIMAL_HYPERS_NORM["Linf"]["α_init"], "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings=s, compare_on="attack")

# %% [markdown]
# ## Compare sample 11*100 with sample 300 fixed init to 5

# %%
s = {**{"norm":"L1", "balanced_init": "False", "top_explore": 10, "fmn_init":True, "targeted_line":False},
**{"level": "sample", "target":"x"}, 
**{"ifmn_α_init":"5"}}
[*logger.where(**s).keys()]
# Out:
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-8',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-1',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-15',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-5',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-12',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-3',
#  'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-balanced_init-False-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Maini2020MultipleAVG-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Engstrom2019Robustness_l2-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Engstrom2019Robustness_linf-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Augustin2020Adversarial_34_10_extra-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Maini2020MultipleAVG-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Engstrom2019Robustness_l2-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Augustin2020Adversarial_34_10_extra-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Rice2020Overfitting-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Xiao2020Enhancing-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Maini2020MultipleMSD-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-10.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Rice2020Overfitting-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleMSD-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Maini2020MultipleMSD-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Rice2020Overfitting-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Engstrom2019Robustness_linf-binary_search_steps-10-loss_f-DL-steps-1000-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Xiao2020Enhancing-eps-12.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Augustin2020Adversarial_34_10_extra-eps-18.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn-model-Xiao2020Enhancing-binary_search_steps-10-loss_f-DL-steps-100-α_final-0.0001-α_init-1-γ_final-0.001-γ_init-0.05',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Maini2020MultipleAVG-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_l2-eps-8.0-loss_f-DL',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Maini2020MultipleAVG-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Maini2020MultipleAVG-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Maini2020MultipleMSD-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Maini2020MultipleMSD-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Augustin2020Adversarial_34_10_extra-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Augustin2020Adversarial_34_10_extra-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Engstrom2019Robustness_l2-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Engstrom2019Robustness_l2-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Rice2020Overfitting-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Rice2020Overfitting-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Xiao2020Enhancing-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Xiao2020Enhancing-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn_all-model-Engstrom2019Robustness_linf-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-alma_all-model-Engstrom2019Robustness_linf-level-sample-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleAVG-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleAVG-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleMSD-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Maini2020MultipleMSD-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Augustin2020Adversarial_34_10_extra-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Augustin2020Adversarial_34_10_extra-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_l2-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_l2-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Rice2020Overfitting-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Rice2020Overfitting-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_linf-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_all-model-Engstrom2019Robustness_linf-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Maini2020MultipleAVG-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Maini2020MultipleAVG-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Maini2020MultipleMSD-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Maini2020MultipleMSD-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Augustin2020Adversarial_34_10_extra-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Augustin2020Adversarial_34_10_extra-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Engstrom2019Robustness_l2-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Engstrom2019Robustness_l2-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Rice2020Overfitting-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Rice2020Overfitting-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Engstrom2019Robustness_linf-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allf-model-Engstrom2019Robustness_linf-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Maini2020MultipleAVG-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Maini2020MultipleAVG-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Maini2020MultipleMSD-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Maini2020MultipleMSD-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Augustin2020Adversarial_34_10_extra-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Augustin2020Adversarial_34_10_extra-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Engstrom2019Robustness_l2-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Engstrom2019Robustness_l2-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Rice2020Overfitting-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Rice2020Overfitting-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Engstrom2019Robustness_linf-α_init-ensemble-steps-101',
#  'dataset-CIFAR10-norm-L1-attack-fmn2_allp-model-Engstrom2019Robustness_linf-steps-101']

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings=s, compare_on="attack")

# %% [markdown]
# ## Compare ifmn_alpha_init

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1", "attack": "fmn2", "α_init":OPTIMAL_HYPERS_NORM["L1"]["α_init"], "target":"x", "balanced_init": "False", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"}, compare_on="ifmn_α_init")

# %%
for key in [*logger.where(**{"model": "Maini2020MultipleMSD","norm": "L1", "ifmn_α_init":"5", "target":"x", "balanced_init": "False", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"}).keys()]:
    print(logger.value_from_id("α_init", key) , key)

# %%
k = "dataset-CIFAR10-norm-L1-attack-fmn2-model-Xiao2020Enhancing-balanced_init-False-binary_search_steps-10-fmn_init-True-ifmn_α_init-5-loss_f-DL-steps-100-targeted_line-False-top_explore-10-α_final-0.0001-α_init-10-γ_init-0.05"

# %%
v = lambda parameter_name, k: k.split(f"-{parameter_name}-")[1].split("-")[0]
v("α_init", k)

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1", "attack":"fmn2","α_init":"1", "target":"x", "balanced_init": "False", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"}, compare_on="ifmn_α_init")

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1", "attack":"fmn2","α_init":"5", "balanced_init": "False","target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"}, compare_on="ifmn_α_init")

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1", "attack":"fmn2","α_init":"10", "target":"x", "balanced_init": "False", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"}, compare_on="ifmn_α_init")

# %% [markdown]
# # COmpare aplha_init given fixed ifmn_alpha_init

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1","ifmn_α_init":"10", "target":"x", "balanced_init": "False", "top_explore": "10", "fmn_init": "True", "targeted_line":"False"}, compare_on="α_init")

# %%
logger.logs_dir="logs_alma"
logger.load_all()

# %%
# FMN 100 untargeted + 100 targeted to each class
# ALMA 100 untargeted + 100 targeted to each class
OPTIMAL_HYPERS=OPTIMAL_HYPERS_NORM
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn", "alma"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm]).keys())] + [*list(logger.where(model=model, attack=attack+"_all", level="norm", **OPTIMAL_HYPERS[norm]).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_all-model-{model}-level-norm-steps-101", quick_ids)

OPTIMAL_HYPERS=OPTIMAL_HYPERS_BEST
for norm in OPTIMAL_HYPERS:
    for model in SCORES[norm][0]:
        if "Xiao" in model or "Kang" in model:
            continue
        for attack in ["fmn", "alma"]:
            run_ids = [*list(logger.where(model=model, attack=attack, **OPTIMAL_HYPERS[norm]).keys())] + [*list(logger.where(model=model, attack=attack+"_all", level="sample", **OPTIMAL_HYPERS[norm]).keys())]
            is_slow = lambda x: logger.get_n_steps(x) > 999
            quick_ids = [*filter(lambda x: not is_slow(x), run_ids)]
            if quick_ids:
                logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-{attack}_all-model-{model}-level-sample-steps-101", quick_ids)
                
OPTIMAL_HYPERS = OPTIMAL_HYPERS_NORM

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L1", "α_init":OPTIMAL_HYPERS_NORM["L1"]["α_init"], "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False", "binary_search_steps":"x"})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "L2", "α_init":OPTIMAL_HYPERS_NORM["L2"]["α_init"], "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False", "binary_search_steps":"x"})

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"norm": "Linf", "α_init":OPTIMAL_HYPERS_NORM["Linf"]["α_init"], "target":"x", "top_explore": "10", "fmn_init": "True", "targeted_line":"False", "binary_search_steps":"x"})

# %%
report = logger.report_ra(logger.where(norm="Linf", top_explore="10", α_init=OPTIMAL_HYPERS_NORM["Linf"]["α_init"]), eps=8/255+0.00001)
report.groupby(["model", "attack"])["rob_acc"].min()
# Out:
# model                                      attack
# Engstrom2019Robustness_linf                aa           0.505
#                                            fmn          0.550
#                                            fmn2         0.510
#                                            fmn2_all     0.510
#                                            fmn2_allf    0.510
#                                            fmn2_allp    0.510
#                                            fmn_all      0.510
#                                            fmn_t        0.740
# Gowal2020Uncovering_70_16_extra            aa           0.695
#                                            fmn          0.695
#                                            fmn2         0.695
#                                            fmn2_all     0.695
#                                            fmn2_allf    0.695
#                                            fmn2_allp    0.695
#                                            fmn_all      0.695
#                                            fmn_t        0.820
# Gowal2021Improving_70_16_ddpm_100m         aa           0.710
#                                            fmn          0.730
#                                            fmn2         0.710
#                                            fmn2_all     0.710
#                                            fmn2_allf    0.710
#                                            fmn2_allp    0.710
#                                            fmn_all      0.710
#                                            fmn_t        0.815
# Gowal2021Improving_R18_ddpm_100m           aa           0.625
#                                            fmn          0.660
#                                            fmn2         0.630
#                                            fmn2_all     0.630
#                                            fmn2_allf    0.630
#                                            fmn2_allp    0.630
#                                            fmn_all      0.625
#                                            fmn_t        0.795
# Kang2021Stable                             aa           0.720
#                                            fmn          0.925
#                                            fmn2         0.915
#                                            fmn_all      0.915
#                                            fmn_t        0.915
# Rade2021Helper_R18_extra                   aa           0.625
#                                            fmn          0.650
#                                            fmn2         0.625
#                                            fmn2_all     0.625
#                                            fmn2_allf    0.625
#                                            fmn2_allp    0.625
#                                            fmn_all      0.625
#                                            fmn_t        0.790
# Rebuffi2021Fixing_70_16_cutmix_extra_linf  aa           0.675
#                                            fmn          0.685
#                                            fmn2         0.675
#                                            fmn2_all     0.675
#                                            fmn2_allf    0.675
#                                            fmn2_allp    0.675
#                                            fmn_all      0.675
#                                            fmn_t        0.815
# Name: rob_acc, dtype: float64

# %%
print("Improvement in rob_acc over plain AA:")
report[report.attack == "aa"].groupby(["model"])["rob_acc"].min() - report[report.attack != "aa"].groupby(["model"])["rob_acc"].min()
# Out:
# Improvement in rob_acc over plain AA:
# model
# Engstrom2019Robustness_linf                 -0.005
# Gowal2020Uncovering_70_16_extra              0.000
# Gowal2021Improving_70_16_ddpm_100m           0.000
# Gowal2021Improving_R18_ddpm_100m             0.000
# Kang2021Stable                              -0.195
# Rade2021Helper_R18_extra                     0.000
# Rebuffi2021Fixing_70_16_cutmix_extra_linf    0.000
# Name: rob_acc, dtype: float64

# %%
report = logger.report_ra(logger.where(norm="L2", top_explore="10", α_init=OPTIMAL_HYPERS_NORM["L2"]["α_init"]), eps=0.5+ 0.00001)
report[(report.attack != "fmn_t") & (report.attack != "alma_t")].groupby(["model", "attack"])["rob_acc"].min()
# Out:
# model                                    attack
# Engstrom2019Robustness_l2                aa           0.700
#                                          alma         0.705
#                                          alma_all     0.705
#                                          fmn          0.715
#                                          fmn2         0.700
#                                          fmn2_all     0.700
#                                          fmn2_allf    0.700
#                                          fmn2_allp    0.700
#                                          fmn_all      0.700
# Gowal2020Uncovering_extra                aa           0.825
#                                          alma         0.825
#                                          alma_all     0.825
#                                          fmn          0.835
#                                          fmn2         0.825
#                                          fmn2_all     0.825
#                                          fmn2_allf    0.825
#                                          fmn2_allp    0.825
#                                          fmn_all      0.825
# Rade2021Helper_R18_ddpm                  aa           0.800
#                                          alma         0.800
#                                          alma_all     0.800
#                                          fmn          0.800
#                                          fmn2         0.800
#                                          fmn2_all     0.800
#                                          fmn2_allf    0.800
#                                          fmn2_allp    0.800
#                                          fmn_all      0.800
# Rebuffi2021Fixing_70_16_cutmix_ddpm      aa           0.850
#                                          alma         0.850
#                                          alma_all     0.850
#                                          fmn          0.850
#                                          fmn2         0.850
#                                          fmn2_all     0.850
#                                          fmn2_allf    0.850
#                                          fmn2_allp    0.850
#                                          fmn_all      0.850
# Rebuffi2021Fixing_70_16_cutmix_extra_l2  aa           0.845
#                                          alma         0.845
#                                          alma_all     0.845
#                                          fmn          0.850
#                                          fmn2         0.845
#                                          fmn2_all     0.845
#                                          fmn2_allf    0.845
#                                          fmn2_allp    0.845
#                                          fmn_all      0.845
# Rebuffi2021Fixing_R18_cutmix_ddpm        aa           0.810
#                                          alma         0.810
#                                          alma_all     0.810
#                                          fmn          0.810
#                                          fmn2         0.810
#                                          fmn2_all     0.810
#                                          fmn2_allf    0.810
#                                          fmn2_allp    0.810
#                                          fmn_all      0.810
# Name: rob_acc, dtype: float64

# %%
print("Improvement in rob_acc over plain AA:")
report[report.attack == "aa"].groupby(["model"])["rob_acc"].min() - report[report.attack != "aa"].groupby(["model"])["rob_acc"].min()
# Out:
# Improvement in rob_acc over plain AA:
# model
# Engstrom2019Robustness_l2                  0.0
# Gowal2020Uncovering_extra                  0.0
# Rade2021Helper_R18_ddpm                    0.0
# Rebuffi2021Fixing_70_16_cutmix_ddpm        0.0
# Rebuffi2021Fixing_70_16_cutmix_extra_l2    0.0
# Rebuffi2021Fixing_R18_cutmix_ddpm          0.0
# Name: rob_acc, dtype: float64

# %%
report = logger.report_ra(logger.where(norm="L1", α_init=OPTIMAL_HYPERS_NORM["L1"]["α_init"]), eps=8+ 0.00001)
report[(report.attack != "fmn_t") & (report.attack != "alma_t")][report.attack != "alma_t"].groupby(["model", "attack"])["rob_acc"].min()
# Out:
# /var/tmp/pbs.11822799.meta-pbs.metacentrum.cz/ipykernel_4117931/4218265514.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   report[(report.attack != "fmn_t") & (report.attack != "alma_t")][report.attack != "alma_t"].groupby(["model", "attack"])["rob_acc"].min()
# model                                attack
# Augustin2020Adversarial_34_10_extra  aa           0.575
#                                      alma         0.650
#                                      alma_all     0.675
#                                      fmn          0.640
#                                      fmn2         0.625
#                                      fmn2_all     0.585
#                                      fmn2_allf    0.625
#                                      fmn2_allp    0.605
#                                      fmn_all      0.590
# Engstrom2019Robustness_l2            aa           0.495
#                                      alma         0.560
#                                      alma_all     0.605
#                                      fmn          0.555
#                                      fmn2         0.535
#                                      fmn2_all     0.505
#                                      fmn2_allf    0.520
#                                      fmn2_allp    0.515
#                                      fmn_all      0.510
# Engstrom2019Robustness_linf          aa           0.170
#                                      alma         0.265
#                                      alma_all     0.255
#                                      fmn          0.315
#                                      fmn2         0.280
#                                      fmn2_all     0.215
#                                      fmn2_allf    0.250
#                                      fmn2_allp    0.230
#                                      fmn_all      0.230
# Maini2020MultipleAVG                 aa           0.640
#                                      alma         0.665
#                                      alma_all     0.665
#                                      fmn          0.645
#                                      fmn2         0.625
#                                      fmn2_all     0.625
#                                      fmn2_allf    0.625
#                                      fmn2_allp    0.625
#                                      fmn_all      0.625
# Maini2020MultipleMSD                 aa           0.600
#                                      alma         0.650
#                                      alma_all     0.640
#                                      fmn          0.600
#                                      fmn2         0.595
#                                      fmn2_all     0.595
#                                      fmn2_allf    0.595
#                                      fmn2_allp    0.595
#                                      fmn_all      0.595
# Rice2020Overfitting                  aa           0.465
#                                      alma         0.575
#                                      alma_all     0.630
#                                      fmn          0.550
#                                      fmn2         0.535
#                                      fmn2_all     0.490
#                                      fmn2_allf    0.505
#                                      fmn2_allp    0.495
#                                      fmn_all      0.495
# Xiao2020Enhancing                    aa           0.280
#                                      alma         0.750
#                                      alma_all     0.675
#                                      fmn          0.490
#                                      fmn2         0.520
#                                      fmn_all      0.485
# Name: rob_acc, dtype: float64

# %%
print("Improvement in rob_acc over plain AA:")
report[report.attack == "aa"].groupby(["model"])["rob_acc"].min() - report[report.attack != "aa"].groupby(["model"])["rob_acc"].min()
# Out:
# Improvement in rob_acc over plain AA:
# model
# Augustin2020Adversarial_34_10_extra   -0.010
# Engstrom2019Robustness_l2             -0.010
# Engstrom2019Robustness_linf           -0.045
# Maini2020MultipleAVG                   0.015
# Maini2020MultipleMSD                   0.005
# Rice2020Overfitting                   -0.025
# Xiao2020Enhancing                     -0.205
# Name: rob_acc, dtype: float64
