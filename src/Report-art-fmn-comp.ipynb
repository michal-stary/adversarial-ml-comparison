# %% [markdown]
# # Comparison of AA init FMN vs normal FMN

# %%
from logging_ import Logger
import matplotlib.pyplot as plt
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logger = Logger(logs_dir="logs_art_comp_fmn")

# %%
logger.load_all()

# %% [markdown]
# # Metrics

# %%
report = logger.report()
report.reset_index(drop=True)
# Out:
#     dataset  norm                                      model attack steps  \
# 0   CIFAR10    L1                          Xiao2020Enhancing    afm   112
# 1   CIFAR10  Linf  Rebuffi2021Fixing_70_16_cutmix_extra_linf    fmn  1001
# 2   CIFAR10    L2          Rebuffi2021Fixing_R18_cutmix_ddpm    afm   112
# 3   CIFAR10  Linf            Gowal2020Uncovering_70_16_extra    fmn   101
# 4   CIFAR10    L2                    Rade2021Helper_R18_ddpm    fmn   101
# ..      ...   ...                                        ...    ...   ...
# 73  CIFAR10  Linf                Engstrom2019Robustness_linf    afm  1012
# 74  CIFAR10    L2        Rebuffi2021Fixing_70_16_cutmix_ddpm    fmn  1001
# 75  CIFAR10  Linf            Gowal2020Uncovering_70_16_extra    afm  1012
# 76  CIFAR10    L1        Augustin2020Adversarial_34_10_extra    afm  1012
# 77  CIFAR10    L2          Rebuffi2021Fixing_R18_cutmix_ddpm    fmn   101
#
#                                                params     median  n_qs    asr
# 0   -binary_search_steps-10-init_aa_eps-12.0-loss_...   9.920694   8.0  100.0
# 1   -binary_search_steps-10-loss_f-DL-steps-1000-α...   0.048344  18.0  100.0
# 2   -binary_search_steps-10-init_aa_eps-0.75-loss_...   1.113635  22.0  100.0
# 3   -binary_search_steps-10-loss_f-DL-steps-100-α_...   0.050001  19.0  100.0
# 4   -binary_search_steps-10-loss_f-DL-steps-100-α_...   1.088176  13.0  100.0
# ..                                                ...        ...   ...    ...
# 73  -binary_search_steps-10-init_aa_eps-0.047059-l...   0.032838   9.0  100.0
# 74  -binary_search_steps-10-loss_f-DL-steps-1000-α...   1.155430  16.0  100.0
# 75  -binary_search_steps-10-init_aa_eps-0.047059-l...   0.048070  24.0  100.0
# 76  -binary_search_steps-10-init_aa_eps-12.0-loss_...  10.417799   6.0  100.0
# 77  -binary_search_steps-10-loss_f-DL-steps-100-α_...   1.113560  12.0  100.0
#
# [78 rows x 9 columns]

# %%
logger.plot_QD_grid(figsize=(60,15))

# %%
logger.plot_SE_grid(figsize=(60,15))
