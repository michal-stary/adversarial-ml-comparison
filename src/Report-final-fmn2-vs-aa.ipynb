# %% [markdown]
# # Investigation of AA+FMN
# FMN added to AA suite

# %%
from logging_ import Logger
import matplotlib.pyplot as plt
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logger = Logger(logs_dir="logs_finaltest")

# %%
logger.load_all()

# %% [markdown]
# # Metrics

# %%
report = logger.report()
report.reset_index(drop=True)
# Out:
#      dataset norm                                model attack steps  \
# 0    CIFAR10   L1                 Maini2020MultipleMSD   fmn2   299
# 1    CIFAR10   L2                      Sehwag2021Proxy   fmn2   501
# 2    CIFAR10   L2    Rebuffi2021Fixing_R18_cutmix_ddpm     aa     2
# 3    CIFAR10   L1                 Maini2020MultipleAVG   fmn2   299
# 4    CIFAR10   L2                      Sehwag2021Proxy     aa     2
# ..       ...  ...                                  ...    ...   ...
# 169  CIFAR10   L2  Augustin2020Adversarial_34_10_extra     aa     2
# 170  CIFAR10   L2              Rade2021Helper_R18_ddpm     aa     2
# 171  CIFAR10   L1                 Maini2020MultipleMSD     aa     2
# 172  CIFAR10   L1                  Rice2020Overfitting   fmn2   299
# 173  CIFAR10   L1          Engstrom2019Robustness_linf   fmn2   299
#
#                                                 params     median   n_qs  \
# 0    -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...  10.953979  228.0
# 1    -balanced_init-False-fmn_init-True-ifmn_α_init...   0.992364   33.0
# 2                                   -eps-0.5-loss_f-DL        inf    0.0
# 3    -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...  11.159771  196.0
# 4                                   -eps-1.0-loss_f-DL   1.000000    1.0
# ..                                                 ...        ...    ...
# 169                                 -eps-1.5-loss_f-DL   1.500000    1.0
# 170                                 -eps-2.0-loss_f-DL   2.000000    1.0
# 171                                  -eps-30-loss_f-DL  30.000000    1.0
# 172  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...   7.528528  208.0
# 173  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...   3.780960  250.0
#
#             asr  first_adv_step  first_last_ratio
# 0    100.000000        5.841000          1.598229
# 1    100.000000        3.494000          2.345351
# 2     15.239155        0.575630          1.000000
# 3    100.000000        6.350000          1.930466
# 4     44.850498        0.806773          1.000000
# ..          ...             ...               ...
# 169   81.798942        0.933575          1.000000
# 170   89.427312        0.898230          1.000000
# 171   87.950311        0.784053          1.000000
# 172  100.000000        5.501000          1.923450
# 173  100.000000       14.310000          2.154094
#
# [174 rows x 11 columns]

# %%
report[report.model == "Engstrom2019Robustness_linf"]
# Out:
#                                                     dataset norm  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  CIFAR10   L1
#
#                                                                           model  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  Engstrom2019Robustness_linf
#
#                                                    attack steps  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...     aa     2
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...     aa     2
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...     aa     2
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...     aa     2
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...     aa     2
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...     aa     2
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   fmn2   299
#
#                                                                                                params  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...                                  -eps-30-loss_f-DL
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...                                  -eps-20-loss_f-DL
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...                                  -eps-12-loss_f-DL
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...                                   -eps-4-loss_f-DL
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...                                   -eps-8-loss_f-DL
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...                                  -eps-16-loss_f-DL
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  -croce_l1-True-fmn_init-True-ifmn_α_init-5-los...
#
#                                                        median   n_qs  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   3.961293  197.0
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   3.861138  259.0
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  30.000000    1.0
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   4.202828  221.0
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  20.000000    1.0
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  12.000000    1.0
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   4.000000    1.0
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   3.992144  258.0
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   8.000000    1.0
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   3.765220  249.0
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  16.000000    1.0
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   4.069393  262.0
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...   3.780960  250.0
#
#                                                            asr  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...  100.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   99.541810
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   93.241695
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   56.815580
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   84.536083
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...   97.709049
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...  100.000000
#
#                                                     first_adv_step  \
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.191000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.310000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...        0.873000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.105000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...        0.872490
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...        0.865037
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...        0.796148
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.289000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...        0.853179
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.397000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...        0.870408
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.356000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...       14.310000
#
#                                                     first_last_ratio
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          2.039637
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          2.105984
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...          1.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          1.758133
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...          1.000000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...          1.000000
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...          1.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          1.972542
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...          1.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          2.143314
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstro...          1.000000
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          1.902195
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engst...          2.154094

# %%
logger.plot_QD_grid(figsize=(60,15))

# %%
logger.plot_SE_grid(figsize=(60,15), where_settings={"α_init":10})

# %% [markdown]
# # ensemble FMN2

# %%
from scores import SCORES

norm = "L1"
## add ensemble for L1:
for model_name in SCORES[norm][0]:
    if "Xiao" in model_name:
        continue
    run_ids = list(logger.where(norm=norm, model=model_name, attack="fmn2").keys())
    print(run_ids)
    # print(logger.dict[run_ids[0]]["norm_progress"][:,:, 0])

    logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-autofmn-model-{model_name}-steps-1001", run_ids)
# Out:
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleAVG-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8']
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Maini2020MultipleMSD-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3']
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1']
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_l2-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5']
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Rice2020Overfitting-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15']
# ['dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15', 'dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5']

# %%
from scores import SCORES

norm = "L2"
## add ensemble for L1:
for model_name in SCORES[norm][0]:
    if "Xiao" in model_name:
        continue
    run_ids = list(logger.where(norm=norm, model=model_name, attack="fmn2", α_init=10).keys())
    print(run_ids)
    if not run_ids:
        continue
    logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-autofmn-model-{model_name}-steps-1001", run_ids)
# Out:
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Rebuffi2021Fixing_70_16_cutmix_extra_l2-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Gowal2020Uncovering_extra-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Rebuffi2021Fixing_70_16_cutmix_ddpm-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Augustin2020Adversarial_34_10_extra-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Sehwag2021Proxy-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Rade2021Helper_R18_ddpm-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Rebuffi2021Fixing_R18_cutmix_ddpm-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']
# ['dataset-CIFAR10-norm-L2-attack-fmn2-model-Engstrom2019Robustness_l2-balanced_init-False-fmn_init-True-ifmn_α_init-10-loss_f-DL-steepest_line-False-steps-319-top_explore-10-track_grad_size-True-α_final-0.0001-α_init-10']

# %%
from scores import SCORES

norm = "Linf"
## add ensemble for L1:
for model_name in SCORES[norm][0]:
    if "Xiao" in model_name:
        continue
    run_ids = list(logger.where(model=model_name).keys())
    logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-autofmn-model-{model_name}-steps-1001", run_ids)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-151-94b3c72fdcff>", line 9, in <cell line: 5>
#     logger.merge(f"dataset-CIFAR10-norm-{norm}-attack-autofmn-model-{model_name}-steps-1001", run_ids)
#   File "/home/mstary/adversarial-ml-comparison/src/logging_.py", line 502, in merge
#     longest_ind = n_steps.index(max(n_steps))
# ValueError: max() arg is an empty sequence
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/mstary/miniconda3/envs/conda_env/lib/python3.8/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
logger.plot_SE_grid(where_settings={"fmn_init":"X"}, figsize=(60,10))

# %%
report = logger.report_ra(logger.where(norm="Linf"), eps=8/255+0.00001)
report.groupby(["model", "attack"])["rob_acc"].min()
# Out:
# Series([], Name: rob_acc, dtype: float64)

# %%
print("Improvement in rob_acc over plain AA:")
report[report.attack == "aa"].groupby(["model"])["rob_acc"].min() - report.groupby(["model"])["rob_acc"].min()
# Out:
# Improvement in rob_acc over plain AA:
# Series([], Name: rob_acc, dtype: float64)

# %%
print("AA advantage over FMN")
report[report.attack == "fmn"].groupby(["model"])["rob_acc"].min() - report[report.attack == "aa"].groupby(["model"])["rob_acc"].min()
# Out:
# AA advantage over FMN
# Series([], Name: rob_acc, dtype: float64)

# %%
report = logger.report_ra(logger.where(norm="L2", α_init=1), eps=0.5+ 0.00001)
report.groupby(["model", "attack"])["rob_acc"].min()
# Out:
# model                                    attack
# Augustin2020Adversarial_34_10_extra      aa         0.789
#                                          autofmn    0.789
#                                          fmn2       0.789
# Engstrom2019Robustness_l2                aa         0.687
#                                          autofmn    0.686
#                                          fmn2       0.686
# Gowal2020Uncovering_extra                aa         0.810
#                                          autofmn    0.810
#                                          fmn2       0.810
# Rade2021Helper_R18_ddpm                  aa         0.756
#                                          autofmn    0.756
#                                          fmn2       0.756
# Rebuffi2021Fixing_28_10_cutmix_ddpm      aa         0.788
#                                          fmn2       0.788
# Rebuffi2021Fixing_70_16_cutmix_ddpm      aa         0.807
#                                          autofmn    0.807
#                                          fmn2       0.807
# Rebuffi2021Fixing_70_16_cutmix_extra_l2  aa         0.824
#                                          autofmn    0.824
#                                          fmn2       0.824
# Rebuffi2021Fixing_R18_cutmix_ddpm        aa         0.762
#                                          autofmn    0.762
#                                          fmn2       0.762
# Sehwag2021Proxy                          aa         0.776
#                                          autofmn    0.776
#                                          fmn2       0.776
# Name: rob_acc, dtype: float64

# %%
report[report.attack=="fmn2"]
# Out:
#     dataset norm                                    model attack steps  \
# 5   CIFAR10   L2      Rebuffi2021Fixing_70_16_cutmix_ddpm   fmn2   501
# 18  CIFAR10   L2                  Rade2021Helper_R18_ddpm   fmn2   501
# 19  CIFAR10   L2      Rebuffi2021Fixing_28_10_cutmix_ddpm   fmn2   501
# 23  CIFAR10   L2                          Sehwag2021Proxy   fmn2   501
# 35  CIFAR10   L2                Gowal2020Uncovering_extra   fmn2   501
# 38  CIFAR10   L2      Augustin2020Adversarial_34_10_extra   fmn2   501
# 42  CIFAR10   L2        Rebuffi2021Fixing_R18_cutmix_ddpm   fmn2   501
# 57  CIFAR10   L2                Engstrom2019Robustness_l2   fmn2   501
# 60  CIFAR10   L2  Rebuffi2021Fixing_70_16_cutmix_extra_l2   fmn2   501
#
#                                                params  rob_acc
# 5   -balanced_init-False-fmn_init-True-ifmn_α_init...    0.807
# 18  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.756
# 19  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.788
# 23  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.776
# 35  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.810
# 38  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.789
# 42  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.762
# 57  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.686
# 60  -balanced_init-False-fmn_init-True-ifmn_α_init...    0.824

# %%
print("Improvement in rob_acc over plain AA:")
report[report.attack == "aa"].groupby(["model"])["rob_acc"].min() - report.groupby(["model"])["rob_acc"].min()
# Out:
# Improvement in rob_acc over plain AA:
# model
# Augustin2020Adversarial_34_10_extra        0.000
# Engstrom2019Robustness_l2                  0.001
# Gowal2020Uncovering_extra                  0.000
# Rade2021Helper_R18_ddpm                    0.000
# Rebuffi2021Fixing_28_10_cutmix_ddpm        0.000
# Rebuffi2021Fixing_70_16_cutmix_ddpm        0.000
# Rebuffi2021Fixing_70_16_cutmix_extra_l2    0.000
# Rebuffi2021Fixing_R18_cutmix_ddpm          0.000
# Sehwag2021Proxy                            0.000
# Name: rob_acc, dtype: float64

# %%
print("AA advantage over FMN")
report[report.attack == "fmn"].groupby(["model"])["rob_acc"].min() - report[report.attack == "aa"].groupby(["model"])["rob_acc"].min()
# Out:
# AA advantage over FMN
# model
# Augustin2020Adversarial_34_10_extra       NaN
# Engstrom2019Robustness_l2                 NaN
# Gowal2020Uncovering_extra                 NaN
# Rade2021Helper_R18_ddpm                   NaN
# Rebuffi2021Fixing_28_10_cutmix_ddpm       NaN
# Rebuffi2021Fixing_70_16_cutmix_ddpm       NaN
# Rebuffi2021Fixing_70_16_cutmix_extra_l2   NaN
# Rebuffi2021Fixing_R18_cutmix_ddpm         NaN
# Sehwag2021Proxy                           NaN
# Name: rob_acc, dtype: float64

# %%
report = logger.report_ra(logger.where(norm="L1"), eps=8+ 0.00001)
report.groupby(["model", "attack"])["rob_acc"].min()
# Out:
# model                                attack
# Augustin2020Adversarial_34_10_extra  aa         0.533
#                                      autofmn    0.560
#                                      fmn2       0.578
# Engstrom2019Robustness_l2            aa         0.422
#                                      autofmn    0.460
#                                      fmn2       0.474
# Engstrom2019Robustness_linf          aa         0.135
#                                      autofmn    0.190
#                                      fmn2       0.219
# Maini2020MultipleAVG                 aa         0.589
#                                      autofmn    0.588
#                                      fmn2       0.595
# Maini2020MultipleMSD                 aa         0.570
#                                      autofmn    0.571
#                                      fmn2       0.573
# Rice2020Overfitting                  aa         0.416
#                                      autofmn    0.454
#                                      fmn2       0.465
# Xiao2020Enhancing                    aa         0.277
# Name: rob_acc, dtype: float64

# %%
print("Improvement in rob_acc over plain AA:")
report[report.attack == "aa"].groupby(["model"])["rob_acc"].min() - report.groupby(["model"])["rob_acc"].min()
# Out:
# Improvement in rob_acc over plain AA:
# model
# Augustin2020Adversarial_34_10_extra    0.000
# Engstrom2019Robustness_l2              0.000
# Engstrom2019Robustness_linf            0.000
# Maini2020MultipleAVG                   0.001
# Maini2020MultipleMSD                   0.000
# Rice2020Overfitting                    0.000
# Xiao2020Enhancing                      0.000
# Name: rob_acc, dtype: float64

# %%
print("AA advantage over FMN")
report[report.attack == "fmn"].groupby(["model"])["rob_acc"].min() - report[report.attack == "aa"].groupby(["model"])["rob_acc"].min()
# Out:
# AA advantage over FMN
# model
# Augustin2020Adversarial_34_10_extra   NaN
# Engstrom2019Robustness_l2             NaN
# Engstrom2019Robustness_linf           NaN
# Maini2020MultipleAVG                  NaN
# Maini2020MultipleMSD                  NaN
# Rice2020Overfitting                   NaN
# Xiao2020Enhancing                     NaN
# Name: rob_acc, dtype: float64

# %%
ks = logger.where(norm="L1", model="Engstrom2019Robustness_linf").keys()

aa_time = 0
fmn_time = 0
for k in ks:
    time = logger.dict[k]["end_time"] - logger.dict[k]["start_time"]
    print(k, time)
    if logger.value_from_id("attack", k) == "aa":
        aa_time += time
    else:
        fmn_time += time
# Out:
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-1 663.8463337421417
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-8 664.1492786407471
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-30-loss_f-DL 261.41621828079224
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-20 663.9841527938843
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-20-loss_f-DL 914.5446088314056
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-12-loss_f-DL 1406.1949338912964
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-4-loss_f-DL 4600.298458099365
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-12 663.7606475353241
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-8-loss_f-DL 2163.486915588379
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-3 664.131564617157
# dataset-CIFAR10-norm-L1-attack-aa-model-Engstrom2019Robustness_linf-eps-16-loss_f-DL 1248.1895115375519
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-15 664.0585761070251
# dataset-CIFAR10-norm-L1-attack-fmn2-model-Engstrom2019Robustness_linf-croce_l1-True-fmn_init-True-ifmn_α_init-5-loss_f-DL-steepest_line-False-steps-117-top_explore-10-track_grad_size-False-α_final-0.0001-α_init-5 664.2447233200073
# dataset-CIFAR10-norm-L1-attack-autofmn-model-Engstrom2019Robustness_linf-steps-1001 663.8463337421417

# %%
aa_time, fmn_time
# Out:
# (10594.13064622879, 5312.021610498428)
