# %%
# !git clone https://github.com/pralab/Fast-Minimum-Norm-FMN-Attack.git

# run cp -r Fast-Minimum-Norm-FMN-Attack fmn
# Out:
# fatal: destination path 'Fast-Minimum-Norm-FMN-Attack' already exists and is not an empty directory.

# %%
# %pip install git+https://github.com/RobustBench/robustbench.git
# %pip install torchvision
# !pip install typing --upgrade
# %pip install robustbench
# %pip install -r fmn/requirements.txt
# %pip install torch
# %pip install matplotlib # add matplotlb to
# Out:
# Collecting git+https://github.com/RobustBench/robustbench.git
#   Cloning https://github.com/RobustBench/robustbench.git to /tmp/pip-req-build-rwx6m6id
#   Running command git clone --filter=blob:none --quiet https://github.com/RobustBench/robustbench.git /tmp/pip-req-build-rwx6m6id
#   Resolved https://github.com/RobustBench/robustbench.git to commit baf658b9b45711bb85919088fe185d3bc69f80a9
#   Preparing metadata (setup.py) ... done
# Collecting autoattack@ git+https://github.com/fra31/auto-attack.git@6482e4d6fbeeb51ae9585c41b16d50d14576aadc#egg=autoattack
#   Cloning https://github.com/fra31/auto-attack.git (to revision 6482e4d6fbeeb51ae9585c41b16d50d14576aadc) to /tmp/pip-install-4jz1ub1l/autoattack_123461bdad8644359415cfc15446c4fe
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack.git /tmp/pip-install-4jz1ub1l/autoattack_123461bdad8644359415cfc15446c4fe
#   Running command git rev-parse -q --verify 'sha^6482e4d6fbeeb51ae9585c41b16d50d14576aadc'
#   Running command git fetch -q https://github.com/fra31/auto-attack.git 6482e4d6fbeeb51ae9585c41b16d50d14576aadc
#   Running command git checkout -q 6482e4d6fbeeb51ae9585c41b16d50d14576aadc
#   Resolved https://github.com/fra31/auto-attack.git to commit 6482e4d6fbeeb51ae9585c41b16d50d14576aadc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.7.1 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (1.11.0)
# Requirement already satisfied: torchvision>=0.8.2 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (0.12.0)
# Requirement already satisfied: torchdiffeq in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (0.2.2)
# Requirement already satisfied: geotorch in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (0.3.0)
# Requirement already satisfied: requests~=2.25.0 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (2.25.1)
# Requirement already satisfied: numpy>=1.19.4 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (1.19.5)
# Requirement already satisfied: Jinja2~=2.11.2 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (2.11.3)
# Requirement already satisfied: tqdm~=4.56.1 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (4.56.2)
# Requirement already satisfied: pandas~=1.2.0 in ./adv_env/lib/python3.8/site-packages (from robustbench==1.0) (1.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in ./adv_env/lib/python3.8/site-packages (from Jinja2~=2.11.2->robustbench==1.0) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./adv_env/lib/python3.8/site-packages (from pandas~=1.2.0->robustbench==1.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in ./adv_env/lib/python3.8/site-packages (from pandas~=1.2.0->robustbench==1.0) (2022.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./adv_env/lib/python3.8/site-packages (from requests~=2.25.0->robustbench==1.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in ./adv_env/lib/python3.8/site-packages (from requests~=2.25.0->robustbench==1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./adv_env/lib/python3.8/site-packages (from requests~=2.25.0->robustbench==1.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./adv_env/lib/python3.8/site-packages (from requests~=2.25.0->robustbench==1.0) (2021.10.8)
# Requirement already satisfied: typing-extensions in ./adv_env/lib/python3.8/site-packages (from torch>=1.7.1->robustbench==1.0) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./adv_env/lib/python3.8/site-packages (from torchvision>=0.8.2->robustbench==1.0) (9.0.1)
# Requirement already satisfied: scipy>=1.4.0 in ./adv_env/lib/python3.8/site-packages (from torchdiffeq->robustbench==1.0) (1.8.0)
# Requirement already satisfied: six>=1.5 in ./adv_env/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas~=1.2.0->robustbench==1.0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: foolbox in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: numpy in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 2)) (1.19.5)
# Requirement already satisfied: torch in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: torchvision in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: dill in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 5)) (0.3.4)
# Requirement already satisfied: cox in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 6)) (0.1.post3)
# Requirement already satisfied: tensorboardX in ./adv_env/lib/python3.8/site-packages (from -r fmn/requirements.txt (line 7)) (2.5)
# Requirement already satisfied: setuptools in ./adv_env/lib/python3.8/site-packages (from foolbox->-r fmn/requirements.txt (line 1)) (60.10.0)
# Requirement already satisfied: requests>=2.24.0 in ./adv_env/lib/python3.8/site-packages (from foolbox->-r fmn/requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in ./adv_env/lib/python3.8/site-packages (from foolbox->-r fmn/requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: scipy in ./adv_env/lib/python3.8/site-packages (from foolbox->-r fmn/requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: eagerpy>=0.30.0 in ./adv_env/lib/python3.8/site-packages (from foolbox->-r fmn/requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: GitPython>=3.0.7 in ./adv_env/lib/python3.8/site-packages (from foolbox->-r fmn/requirements.txt (line 1)) (3.1.27)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./adv_env/lib/python3.8/site-packages (from torchvision->-r fmn/requirements.txt (line 4)) (9.0.1)
# Requirement already satisfied: grpcio in ./adv_env/lib/python3.8/site-packages (from cox->-r fmn/requirements.txt (line 6)) (1.44.0)
# Requirement already satisfied: py3nvml in ./adv_env/lib/python3.8/site-packages (from cox->-r fmn/requirements.txt (line 6)) (0.2.7)
# Requirement already satisfied: psutil in ./adv_env/lib/python3.8/site-packages (from cox->-r fmn/requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: tqdm in ./adv_env/lib/python3.8/site-packages (from cox->-r fmn/requirements.txt (line 6)) (4.56.2)
# Requirement already satisfied: protobuf>=3.8.0 in ./adv_env/lib/python3.8/site-packages (from tensorboardX->-r fmn/requirements.txt (line 7)) (3.19.4)
# Requirement already satisfied: six in ./adv_env/lib/python3.8/site-packages (from tensorboardX->-r fmn/requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./adv_env/lib/python3.8/site-packages (from GitPython>=3.0.7->foolbox->-r fmn/requirements.txt (line 1)) (4.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./adv_env/lib/python3.8/site-packages (from requests>=2.24.0->foolbox->-r fmn/requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in ./adv_env/lib/python3.8/site-packages (from requests>=2.24.0->foolbox->-r fmn/requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./adv_env/lib/python3.8/site-packages (from requests>=2.24.0->foolbox->-r fmn/requirements.txt (line 1)) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./adv_env/lib/python3.8/site-packages (from requests>=2.24.0->foolbox->-r fmn/requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: xmltodict in ./adv_env/lib/python3.8/site-packages (from py3nvml->cox->-r fmn/requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./adv_env/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.0.7->foolbox->-r fmn/requirements.txt (line 1)) (5.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in ./adv_env/lib/python3.8/site-packages (1.11.0)
# Requirement already satisfied: typing-extensions in ./adv_env/lib/python3.8/site-packages (from torch) (4.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 9.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.17 in ./adv_env/lib/python3.8/site-packages (from matplotlib) (1.19.5)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in ./adv_env/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in ./adv_env/lib/python3.8/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in ./adv_env/lib/python3.8/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./adv_env/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.1-py3-none-any.whl (899 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.4/899.4 KB 9.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six>=1.5 in ./adv_env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.31.1 kiwisolver-1.4.0 matplotlib-3.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from robustbench.utils import load_model
# Load a model from the model zoo
model = load_model(model_name='Standard', dataset='cifar10', threat_model='Linf')


# # Evaluate the Linf robustness of the model using AutoAttack
# from robustbench.eval import benchmark
# clean_acc, robust_acc = benchmark(model,
#                                   dataset='cifar10',
#                                   threat_model='Linf')

# %%
from fmn.src.attacks.fmn import L1FMNAttack
import foolbox as fb
import torch
import torchvision.datasets as datasets
from foolbox import Misclassification
from fmn.src.utils.data import create_loaders
from fmn.src.utils.show_digit import show_image

# %%
device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'

cifar_trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=None)
cifar_testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=None)


num_batches = 1
batch_size = 20
n_workers = 1
data_loader = create_loaders("./data", task_config="CIFAR10",
                             batch_size=batch_size,
                             transform=None,
                             random_state=0,
                             n_workers=n_workers)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
images, labels = next(iter(data_loader))
images, labels = images.to(device), labels.to(device)

model = model
fmodel = fb.PyTorchModel(model, bounds=(0, 1))
attack = L1FMNAttack()
advs, _, is_adv = attack(fmodel, images, Misclassification(labels), epsilons=None)

# %%
diffs = advs - images
preds = fmodel(advs).argmax(-1)
title = attack.__class__.__name__
show_image(title, images, advs, preds, labels, n_display=8,
               img_shape=images[0].shape)
